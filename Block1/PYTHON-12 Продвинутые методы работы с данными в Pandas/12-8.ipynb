# %%
import re 
import pandas as pd

def get_year_release(arg):
    candidates = re.findall(r'\(\d{4}\)', arg)  
    if len(candidates) > 0:
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        return None
rating=pd.read_csv('data/ratings_movies.csv')
rating_df=rating.copy()
rating_df['year']=get_year_release(rating_df['title'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 14
#      12 rating=pd.read_csv('data/ratings_movies.csv')
#      13 rating_df=rating.copy()
# ---> 14 rating_df['year']=get_year_release(rating_df['title'])
#
# Cell In[8], line 5, in get_year_release(arg)
#       4 def get_year_release(arg):
# ----> 5     candidates = re.findall(r'\(\d{4}\)', arg)
#       6     if len(candidates) > 0:
#       7         year = candidates[0].replace('(', '')
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'Series'
