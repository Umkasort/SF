# %%
import pandas as pd
melb_data=pd.read_csv('data/melb_data_fe.csv')
melb_df=melb_data.copy()
melb_df.pivot_table(values='Price',index='Rooms',columns='Type',fill_value=0).round()
melb_df.pivot_table(values='Price',columns='Weekend',index='Regionname',aggfunc='count')
melb_df.pivot_table(values='Price',index=['SellerG'],columns='Type',aggfunc=['median'],fill_value=0)
# Out:
#                 median
# Type             house townhouse    unit
# SellerG
# Alexkarbon     1036250    935000  560000
# Barry           830000    727500  502000
# Bells           692500    430500  457500
# Biggin         1151750    675000  548000
# Brad            875000    700000  465000
# Buckingham      830000    820000  553000
# Burnham         922500         0  305000
# Buxton         1323750   1030000  670000
# C21             836500    768750  625500
# Cayzer         1505000   1450000  707500
# Chisholm       1520000    950000  640000
# Collins        1566500    930000  592000
# Douglas         684000    500000  494500
# Eview           760000    597500  602000
# Fletchers      1390000   1238000  653000
# Gary           1370000    993500  550000
# Greg           1330000    900000  547500
# HAR             695000         0  518000
# Harcourts       740000    653750  500000
# Hodges         1500000   1105000  605500
# Jas             935000    699000  455000
# ...

# %% [markdown]
# Сгруппируйте данные по признаку количества комнат и найдите среднюю цену объектов недвижимости в каждой группе. В качестве ответа запишите количество комнат, для которых средняя цена наибольшая.

# %%
import pandas as pd
melb_data=pd.read_csv('data/melb_data_fe.csv')
melb_df=melb_data.copy()
melb_df.groupby('Rooms')['Price'].agg(['mean']).sort_values(by=['mean'],ascending=False).iloc[0]
# Out:
# mean    1920700.0
# Name: 7, dtype: float64

# %% [markdown]
# Какой регион имеет наименьшее стандартное отклонение по географической широте (Lattitude)?
# В качестве ответа запишите название этого региона.

# %%
melb_df.groupby('Regionname')['Lattitude'].agg(['std']).sort_values(by=['std'],ascending=True).iloc[0]
# Out:
# std    0.011579
# Name: Western Victoria, dtype: float64

# %% [markdown]
# Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?
# Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.

# %%
melb_df['Date']=pd.to_datetime(melb_df['Date'])
mask1 = melb_df['Date']>='2017.05.01'
mask2 = melb_df['Date']<='2017.09.30'
melb_df.groupby('SellerG')['Price'].agg(['sum']).sort_values(by=['sum'],ascending=True)
# Out:
#                         sum
# SellerG
# LITTLE         2.199300e+07
# Burnham        2.614650e+07
# Moonee         2.878050e+07
# Thomson        2.981600e+07
# Bells          3.038450e+07
# Alexkarbon     3.465559e+07
# Buckingham     3.881160e+07
# Eview          4.065124e+07
# McDonald       4.205350e+07
# Purplebricks   4.360900e+07
# Philip         4.703580e+07
# HAR            4.818300e+07
# O'Brien        4.999551e+07
# C21            5.350800e+07
# Douglas        6.429010e+07
# Rendina        6.600628e+07
# Cayzer         6.867000e+07
# RW             7.013100e+07
# Nick           7.531900e+07
# Collins        7.674250e+07
# Chisholm       7.834425e+07
# Love           7.894540e+07
# Raine          8.946020e+07
# YPA            9.273035e+07
# Stockdale      1.064608e+08
# Williams       1.156803e+08
# Village        1.235205e+08
# Harcourts      1.328355e+08
# Gary           1.671684e+08
# Sweeney        1.805233e+08
# Hodges         2.062959e+08
# Miles          2.130829e+08
# ...
