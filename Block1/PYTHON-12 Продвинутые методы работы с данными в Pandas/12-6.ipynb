# %%
import pandas as pd
import numpy as np
import datetime as dt
import os as os
movies_data=pd.read_csv('data/movies.csv')
movies_df=movies_data.copy()
movies_df['title'].describe()
rate1_data=pd.read_csv('data/ratings1.csv')
rate1_df=rate1_data.copy()
rate1_df.describe
date_df=pd.read_csv('data/dates.csv').copy()
rate1_df['year']=pd.to_datetime(date_df['date']).dt.year
rate1_data.sort_values(b)
rate1_df['year'].value_counts().max
c=list()
c.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 13
#      10 date_df=pd.read_csv('data/dates.csv').copy()
#      11 rate1_df['year']=pd.to_datetime(date_df['date']).dt.year
# ---> 13 rate1_df['year'].value_counts().max[0]
#
# TypeError: 'method' object is not subscriptable
